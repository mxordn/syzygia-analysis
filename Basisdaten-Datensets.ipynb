# %%
import pandas as pd

JohannDF = pd.read_json("schein-datenset.json")

# %%
JohannDF
# Out:
#                       StimmenZahl TrigaKlasse TrigaAttribut  \
#                                 1           M   Einzeltoene
# P4--P4                          3          TA
# P4--P4--m6                      4          TI        remota
# M3--m6                          3          TA
# M3--P5                          3          TP          prop
# ...                           ...         ...           ...
# m3--P5--P8--M9--P11             6          TA
# m3--P5--P8--m10--P12            6          TI         pcomp
# P4--P5--P8--m10--P12            6          TA
# P5--P5--P8--m10--P12            6          TI         icomp
# P5--P5--P8--P11--M13            6          TA
#
#                            IntervallStruktur  Anzahl   Dauer  \
#                                           []     146  224.25
# P4--P4                              [P4, P4]       9    7.25
# P4--P4--m6                      [P4, P4, m6]       1    2.00
# M3--m6                              [M3, m6]      32   28.00
# ...
